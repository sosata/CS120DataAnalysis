# %%
# extract top locations and reasons from feature files

def get_top(xs, n):
    
    x_all = [x_ for x in xs for x_ in x]
    x_uniq = list(set(x_all))
    
    print x_uniq
    
    freq = []
    for i in range(len(x_uniq)):
        freq.append(0)
        for j in range(len(xs)):
            if x_uniq[i] in xs[j]:
                freq[i] += 1

    ind_sort = sorted(range(len(freq)), key=lambda k: freq[k], reverse=True)
    freq_sorted = [freq[i] for i in ind_sort]
    x_uniq_sorted = [x_uniq[i] for i in ind_sort]

    freq_top = freq_sorted[:n]
    x_top = x_uniq_sorted[:n]

    return x_top, freq_top

# %%
# extract top locations
import os
import pickle

data_dir = 'features/'
files = os.listdir(data_dir)

reasons = []
locations = []
for (i,filename) in enumerate(files):
#     print i,
    with open(data_dir+filename) as f:
        feature, target = pickle.load(f)
    f.close()

    reasons.append(list(target['reason']))
    locations.append(list(target['location']))
        
loc_top, loc_freq = get_top(locations, 10)
reason_top, reason_freq = get_top(reasons, 10)

with open('top_locations.dat','w') as f:
    pickle.dump(loc_top, f)
f.close()
with open('top_reaons.dat','w') as f:
    pickle.dump(reason_top, f)
f.close()
# Out:
# ['', 'Bath & Body Works', "Son's school", "Survey, Wasn't in this town, Therapy, Car Dealership", 'college , school, woods', "don't know , Another's Home", 'bus stop, school', 'Los Angeles Trade Tech', 'side of the road', 'office, home development', "Home, Another's Home", "friend's", 'charles hotel', 'urgent care', 'Neighborhood, Gas Station, unknown , grocery', 'Brandon Smith work', 'family members house', 'vet', 'Dr appt', 'Ice Rink', 'parking lot, Road/ Traveling', 'childs work', 'storage garage, storage unit, photo studio, office, home development', 'in route', 'winnebago County correctional facility, post office', 'Rutledge primary , funeral home, Smith and Reagan Funeral Home, store, friends house', 'school, Professional or Medical Office', 'Gaylor Electric', 'Gaithersburg High School, Bank of America', 'Chinese take out', 'my sisters', 'Travel or Transport (Airport, Bus Stop, Train Station, Etc.), Arts & Entertainment (Theater, Music Venue, Etc.)', 'FMC Carswell (prison)', 'post office, government dmv', 'Community Services - Head Start, School, Bank', 'Bowling', 'holiday show', 'Chester county', 'rest stop', 'Vehicle, Travel or Transport (Airport, Bus Stop, Train Station, Etc.)', 'school', 'Daycare , SH Training , group meeting', 'humane society', 'Arts & Entertainment (Theater, Music Venue, Etc.), Spiritual (Church, Temple, Etc.)', 'Foley Middle School', 'Parking Garage', 'Nursing home, Spiritual (Church, Temple, Etc.)', 'on the way home.', '?', 'real estate', 'Vehicle, Nightlife Spot (Bar, Club)', 'rent office', "oreily's", "spouse's work", 'marriot hotel', 'neighborhood', 'transport, friend visit', "I don't know where this is?, Shop or Store", 'Norcom SPIN', 'Nightlife Spot (Bar, Club), Arts & Entertainment (Theater, Music Venue, Etc.)', 'unknown ping location', 'nail', 'lawyer', 'Cal State east bay', 'stopped in traffic', 'laundry ,', 'spouse workplace', 'school, Spiritual (Church, Temple, Etc.)', 'woods, Outdoors & Recreation', 'grocery shopping', 'VLA', 'rental property', 'Beauty Salon', 'doctors appointment', 'Hardware Store', 'another city', 'skyview', 'Spiritual (Church, Temple, Etc.)', 'friends house,', 'Barber shop', 'Dance studio', 'nonexistent', 'SH Training , group meeting', 'I am at home and not at another location', 'Apartment Complex office', 'group meeting', 'Bible Study fellowship, Southcliff', 'Fitzgerald Elementary School', "Professional or Medical Office, Another's Home", "I wasn't here at all today?", 'car wash, friends house,', 'casino', 'airport', 'High School', "store, friends house, Another's Home", 'Home', 'Gas Station', 'new home community', 'Food (Restaurant, Cafe), Outdoors & Recreation, Shop or Store', 'Shop or Store', 'truck stop gas', 'Work, Spiritual (Church, Temple, Etc.)', 'bank, Home', 'rental property , this is an error. ', 'school, school', 'Food (Restaurant, Cafe), Shop or Store, gas station', 'Doctors appointment', 'Outdoors & Recreation, Gym or Other Exercise, Arts & Entertainment (Theater, Music Venue, Etc.)', '., Work', 'Latta Elementary school', 'Food (Restaurant, Cafe), Professional or Medical Office', 'Convalescent Home, none, School', "Travel or Transport (Airport, Bus Stop, Train Station, Etc.), Another's Home", 'Mall or Shopping Center', 'hospital', 'UPS', 'Family Shelter Service', 'Work, school', 'Travel or Transport (Airport, Bus Stop, Train Station, Etc.), Food (Restaurant, Cafe)', "Parent's home", 'Arts & Entertainment (Theater, Music Venue, Etc.), Outdoors & Recreation', 'ace hardware', "Another's Home, Professional or Medical Office", 'trick or treat neighbor', 'laundry', 'Walking', 'Gym or Other Exercise, Arts & Entertainment (Theater, Music Venue, Etc.)', 'Outdoors & Recreation, Nightlife Spot (Bar, Club)', 'nail salon, Shop or Store', "my son's speech therapy for his stutter, orthodontics, Dental surgery", 'car repair shop', 'none', 'Arts & Entertainment (Theater, Music Venue, Etc.), School', "Another's Home", 'Shop or Store, Outdoors & Recreation', 'Library', ...
# ['', 'daughter fitted for wrist brace', 'friends work', 'in route', "dad's home,socialize,christmas", 'shopping,pharmacy', 'in traffic', 'woods', 'groceries', 'socialize,bible study', 'charles hotel', 'gocery shopping', 'urgent care', 'entertainment,watched movie', 'travelling / traffic,vet', 'vet', 'pizza hut', 'hunting', 'fiance has cancer', 'dining,travelling / traffic', 'errand,medical', 'church meeting', 'errand,exercise', "dr. brown's office", 'childs work', 'i am at home and not at another location', 'home,work,other', 'volunteer', "son's teeth cleaning", 'coffee and fuel', 'hospital,daughter', 'appointment', 'car wash,errand', 'my sisters', 'dining,talk to husband/manager', 'furniture store', 'christmas midnight mass', 'meet sister', 'exercise,entertainment', 'needed milk', 'dr. appt.', 'errand,shopping', "i didn't visit this place", 'entertainment,home,work,socialize', ',work', 'to purchase furniture', 'school', 'errand,dining', 'home,pick out a few household items', 'other,home', 'husbands dr appointment', "no idea what this place is. didn't go there.", 'groceries,other', 'dining,christmas party', 'real estate', 'sleep', 'errand,bank', 'clothes', 'errand,get food,socialize', 'helping at food pantry', 'entertainment,errand,socialize,shop', 'cheer competition', 'travelling / traffic,dining', 'hair appt', 'food shopping,gas station', 'unknown ping location', 'errand,tow yard', 'nail', "husband's dental work", 'dental office', 'errand,doctor', 'stopped in traffic', 'dining,work,socialize', 'on way to friends house,on way to church', 'beauty supplies', 'deposit money', 'spiritual,socialize', 'grocery shopping', 'wedding ceremony', 'doctors appointment', 'dr. appointments', 'entertainment,socialize,hotel', 'child was admitted', 'visiting family,socialize', 'home,to visit family', 'purchasing a gift,looking for a gift', 'medical appointment', 'exercise', "doctor's appointment", 'didnt go anywhere', 'pediatritian checkup', 'casino,socialize,travelling / traffic,entertainment', 'daughter had job interview,gym exercise', 'to. shop', 'funeral', 'home,my apt complex', 'travelling / traffic,home', 'returning stepson to his home', 'nonexistent', 'socialize', 'dining,socialize,paintball event', 'buy christmas tree', 'get family pictures', 'dining,entertainment,socialize', 'trick .org treating', 'pick up a few house hold items,pick up lab results', 'attend midnight mass', 'airport', 'survey', 'exercise,travelling / traffic,dining', 'neurologist', 'dining,socialize,work', 'casino', 'church,socialize', 'homecoming', 'errand,socialize,work', 'medical appt', 'exercise,dining', 'gas station,dining', 'bible study', 'apt', 'appointment with attorney', "my child's school", 'daughter needs another surgery', "didn't visit", 'drop off kids to work', 'errand,lifestyle', 'dolar tree', 'entertainment,errand,socialize', "doctor's visit", 'driving,other', 'buy food', 'entertainment,socialize,holiday at my sons place', 'donuts', 'hospital', 'check on feral cats', 'home,entertainment', " i wasn't here,unknown", 'holiday shopping,errand', 'sharins school of dance', 'socialize,babysitting', 'pumpkin patch', 'dining,exercise', 'family visit', "restaurant but didn't stay", "my son's speech therapy for his stutter", 'home,moving my car into the garagr,other,check on feral cats', 'test drive', 'relax', "didn't", 'daughters research project', 'dining,christmas shopping', 'halloween customes', 'festival', 'goodwill shopping', 'socialize,pick up/drive family', 'groceries,shopping', 'looking,shop', 'none', 'home,check on feral cats', 'shopping,medical', 'doctor appointment', 'work', 'home,work', 'movies', "mom's", 'dining,socialize,travelling / traffic', 'socialize,friends meeting place', 'errand,pharmacy', ',errand,lab vlsit', 'loading onto a trailer', 'work project', 'dining,drop off daughter class', 'entertainment,trivia', 'religious service', 'chicken feed', 'gateway church,church service', 'to visit family', 'staying temporarily', 'wedding venue', 'fiance ...

# %%
print loc_top
print loc_freq
print reason_top
print reason_freq
# Out:
# ['Shop or Store', 'Home', 'Food (Restaurant, Cafe)', "Another's Home", 'Professional or Medical Office', 'Work', 'Arts & Entertainment (Theater, Music Venue, Etc.)', 'Outdoors & Recreation', 'Spiritual (Church, Temple, Etc.)', 'Vehicle']
# [197, 196, 183, 160, 136, 111, 84, 79, 49, 48]
# ['home', 'errand', 'dining', 'socialize', 'work', 'entertainment', 'travelling / traffic', 'socialize,dining', 'exercise', 'dining,socialize']
# [191, 187, 170, 157, 133, 92, 67, 65, 49, 49]

# %%
print sorted(['socialize','dining'])
# Out:
# ['dining', 'socialize']
