# %%
# this program uses short-term features from features_new/ and adds personal, long-term features to them

import os
import pickle
import numpy as np
import pandas as pd

ind_lat = 51
ind_long = 52
threshold_distance_squared = 0.0005**2 # equivalent to about 50 meters

save_results = True

feature_dir = 'features/'
feature_out = 'features_long/'

files = os.listdir(feature_dir)

for filename in files:
#     print filename, 
    with open(feature_dir+filename) as f:  
        feature, target = pickle.load(f)
        print feature.shape
        rf = pd.DataFrame(columns=['LT frequency'])
        ai = pd.DataFrame(columns=['LT interval mean'])
        for i in range(feature.shape[0]):
            dist_squared = (feature.loc[:,'lat mean'] - feature.loc[i,'lat mean'])**2 + \
            (feature.loc[:,'lng mean'] - feature.loc[i,'lng mean'])**2
            ind_same = dist_squared<threshold_distance_squared
            # relative frequency
            rf.loc[i] = np.sum(ind_same)/float(feature.shape[0])
            # average interval between visits
            ai.loc[i] = np.mean(np.diff(np.where(ind_same)[0]))
        
        feature = pd.concat([feature, rf, ai], axis=1)
        
    f.close()
    
    if save_results:
        with open(feature_out+filename, 'w') as f:
            pickle.dump([feature, target], f)
        f.close()
# Out:
# (96, 53)
# (154, 53)
# (28, 53)
# (98, 53)
# (79, 53)
# (137, 53)
# (187, 53)
# (126, 53)
# (124, 53)
# (102, 53)
# (171, 53)
# (140, 53)
# (143, 53)
# (109, 53)
# (23, 53)
# (136, 53)
# (208, 53)
# (134, 53)
# (134, 53)
# (35, 53)
# (112, 53)
# (53, 53)
# (157, 53)
# (112, 53)
# (19, 53)
# (242, 53)
# (164, 53)
# (110, 53)
# (33, 53)
# (67, 53)
# (59, 53)
# (29, 53)
# (113, 53)
# (153, 53)
# (395, 53)
# (126, 53)
# (204, 53)
# (117, 53)
# (23, 53)
# (127, 53)
# (93, 53)
# (106, 53)
# (95, 53)
# (172, 53)
# (119, 53)
# (102, 53)
# (102, 53)
# (135, 53)
# (195, 53)
# (82, 53)
# (104, 53)
# (149, 53)
# (137, 53)
# (138, 53)
# (79, 53)
# (59, 53)
# (139, 53)
# (120, 53)
# (140, 53)
# (106, 53)
# (129, 53)
# (136, 53)
# (112, 53)
# (49, 53)
# (120, 53)
# (77, 53)
# (56, 53)
# (145, 53)
# (52, 53)
# (57, 53)
# (117, 53)
# (147, 53)
# (218, 53)
# (65, 53)
# (276, 53)
# (273, 53)
# (28, 53)
# (129, 53)
# (87, 53)
# (166, 53)
# (134, 53)
# (124, 53)
# (50, 53)
# (132, 53)
# (43, 53)
# (272, 53)
# (216, 53)
# (239, 53)
# (65, 53)
# (69, 53)
# (189, 53)
# (122, 53)
# (95, 53)
# (431, 53)
# (82, 53)
# (120, 53)
# (138, 53)
# (81, 53)
# (102, 53)
# (55, 53)
# (100, 53)
# (226, 53)
# (53, 53)
# (274, 53)
# (172, 53)
# (78, 53)
# (37, 53)
# (165, 53)
# (151, 53)
# (123, 53)
# (116, 53)
# (114, 53)
# (117, 53)
# (89, 53)
# (690, 53)
# (78, 53)
# (201, 53)
# (53, 53)
# (143, 53)
# (124, 53)
# (37, 53)
# (79, 53)
# (185, 53)
# (136, 53)
# (125, 53)
# (112, 53)
# (8, 53)
# (107, 53)
# (87, 53)
# (129, 53)
# (77, 53)
# (111, 53)
# (124, 53)
# (129, 53)
# (83, 53)
# (185, 53)
# (186, 53)
# (145, 53)
# (105, 53)
# (98, 53)
# (139, 53)
# (127, 53)
# (128, 53)
# (37, 53)
# (159, 53)
# (68, 53)
# (82, 53)
# (129, 53)
# (125, 53)
# (199, 53)
# (138, 53)
# (13, 53)
# (141, 53)
# (119, 53)
# (82, 53)
# (272, 53)
# (105, 53)
# (64, 53)
# (45, 53)
# (247, 53)
# (172, 53)
# (93, 53)
# (91, 53)
# (123, 53)
# (120, 53)
# (33, 53)
# (141, 53)
# (127, 53)
# (29, 53)
# (194, 53)
# (181, 53)
# (51, 53)
# (89, 53)
# (128, 53)
# (160, 53)
# (130, 53)
# (154, 53)
# (161, 53)
# (118, 53)
# (134, 53)
# (117, 53)
# (177, 53)
# (8, 53)
# (144, 53)
# (116, 53)
# (187, 53)
# (177, 53)
# (76, 53)
# (137, 53)
# (101, 53)
# (147, 53)
# (185, 53)
# (177, 53)
# (16, 53)
# (131, 53)
# (163, 53)
# (151, 53)
# (63, 53)
# (259, 53)
# (112, 53)
# (39, 53)
# (108, 53)
# (74, 53)
# (84, 53)

# %%
target
# Out:
#                                              location         reason  \
# 0                                                Home           home
# 1                                                Home           home
# 2                             Food (Restaurant, Cafe)         dining
# 3                                      Another's Home      socialize
# 4                                                Home           home
# 5                             Food (Restaurant, Cafe)         dining
# 6                                                Home           home
# 7                             Food (Restaurant, Cafe)         dining
# 8                                                Home           home
# 9                             Food (Restaurant, Cafe)         dining
# 10                                               Home           home
# 11                                                vet            vet
# 12                                      Shop or Store         errand
# 13                                      Shop or Store         errand
# 14                                               Home           home
# 15                                               Home           home
# 16                                               Home           home
# 17                            Food (Restaurant, Cafe)         dining
# 18                                               Home           home
# 19                                               Home           home
# 20                                               Home           home
# 21                                               Home           home
# 22                                               Home           home
# 23                                               Home           home
# 24                            Food (Restaurant, Cafe)         dining
# 25                                      Shop or Store         errand
# 26                                               Home           home
# 27                                             school         school
# 28                                               Home           home
# 29                                     Another's Home      socialize
# ..                                                ...            ...
# 54                                               Home           home
# 55                                               Home           home
# 56                                               Home           home
# 57                            Food (Restaurant, Cafe)      socialize
# 58                                               Home           home
# 59                                               Home           home
# 60                                               Home           home
# 61                                               Home           home
# 62                                      Shop or Store       shopping
# 63                     Professional or Medical Office        dentist
# 64                                               Home           home
# 65                                     Another's Home      socialize
# 66                            Food (Restaurant, Cafe)         dining
# 67                                      Shop or Store         errand
# 68                                     Another's Home      socialize
# 69                                               Home           home
# 70                                               Home           home
# 71  Arts & Entertainment (Theater, Music Venue, Etc.)  entertainment
# 72                                               Home           home
# 73                                               Home           home
# 74                                               Home           home
# 75                            Food (Restaurant, Cafe)         dining
# 76                                      Shop or Store         errand
# 77                                      Shop or Store         errand
# 78                                               Home           home
# 79                                               Home           home
# 80                            Food (Restaurant, Cafe)         dining
# 81                                               Home           home
# 82                                               Home           home
# 83                                               Home           home
#
#     accomplishment  pleasure  \
# 0              6.0       6.0
# 1              6.0       6.0
# 2              7.0       7.0
# 3              6.0       6.0
# 4              6.0       6.0
# 5              7.0       7.0
# 6              6.0       6.0
# 7              7.0       7.0
# 8              6.0       6.0
# 9              7.0       7.0
# 10             6.0       6.0
# 11             6.0       6.0
# 12             6.0       6.0
# 13             6.0       6.0
# 14             6.0       6.0
# 15             6.0       6.0
# 16             6.0       6.0
# 17             7.0       7.0
# 18             6.0       6.0
# 19             6.0       6.0
# 20             6.0       6.0
# 21             6.0       6.0
# 22             6.0       6.0
# 23             6.0       6.0
# 24             6.0       6.0
# 25             6.0       6.0
# 26             6.0       6.0
# 27             6.0       6.0
# 28             6.0       6.0
# 29             6.0       6.0
# ..             ...       ...
# 54             6.0       6.0
# 55             6.0       6.0
# 56             6.0       6.0
# 57             6.0       6.0
# 58             6.0       6.0
# 59             6.0       6.0
# 60             6.0       6.0
# 61             7.0       7.0
# 62             6.0       7.0
# 63             6.0       6.0
# 64             6.0       6.0
# 65             6.0       6.0
# 66             6.0       6.0
# 67             6.0       6.0
# 68             6.0       6.0
# 69             6.0       5.0
# 70             6.0       6.0
# 71             7.0       7.0
# 72             6.0       6.0
# 73             6.0       6.0
# 74             6.0       6.0
# 75             7.0       7.0
# 76             6.0       6.0
# 77             6.0       6.0
# 78             6.0       6.0
# 79             6.0       6.0
# 80             7.0       7.0
# 81             7.0       6.0
# 82             6.0       6.0
# 83             6.0       6.0
#
#                                                   fsq
# 0                                             Unknown
# 1                                             Unknown
# 2                                             Unknown
# 3   Travel or Transport (Airport, Bus Stop, Train ...
# 4                                             Unknown
# 5                                       Shop or Store
# 6                                             Unknown
# 7                                       Shop or Store
# 8                                             Unknown
# 9                                       Shop or Store
# 10                                            Unknown
# 11                     Professional or Medical Office
# 12                            Food (Restaurant, Cafe)
# 13                                      Shop or Store
# 14                              Outdoors & Recreation
# 15                                            Unknown
# 16                                            Unknown
# 17                            Food (Restaurant, Cafe)
# 18                              Outdoors & Recreation
# 19                                            Unknown
# 20                                            Unknown
# 21                                            Unknown
# 22                                            Unknown
# 23                              Outdoors & Recreation
# 24                                            Unknown
# 25                                      Shop or Store
# 26                                            Unknown
# 27                     Professional or Medical Office
# 28                                            Unknown
# 29  Travel or Transport (Airport, Bus Stop, Train ...
# ..                                                ...
# 54                                            Unknown
# 55                                            Unknown
# 56                                            Unknown
# 57                            Food (Restaurant, Cafe)
# 58                                            Unknown
# 59                                            Unknown
# 60                                            Unknown
# 61                                            Unknown
# 62                                      Shop or Store
# 63                     Professional or Medical Office
# 64                                            Unknown
# 65                     Professional or Medical Office
# 66                            Food (Restaurant, Cafe)
# 67                              Outdoors & Recreation
# 68  Travel or Transport (Airport, Bus Stop, Train ...
# 69                                            Unknown
# 70                                            Unknown
# 71                                            Unknown
# 72                                            Unknown
# 73                                            Unknown
# 74                                            Unknown
# 75                            Food (Restaurant, Cafe)
# 76                                      Shop or Store
# 77                                      Shop or Store
# 78                                            Unknown
# 79                                            Unknown
# 80                                            Unknown
# 81                                            Unknown
# 82                                            Unknown
# 83                                            Unknown
#
# [84 rows x 5 columns]
