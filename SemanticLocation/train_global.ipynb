# %%
import os
import pickle
import numpy as np
import xgboost as xgb
from calculate_confusion_matrix import calculate_confusion_matrix
import time
from copy import deepcopy
# from sklearn.preprocessing import OneHotEncoder
# from sklearn import preprocessing

save_results = True
do_stratify = False

ft_dir = 'features_long/'

# list feature files
files = os.listdir(ft_dir)

# reading top 10 locations
with open('top10location.dat') as f:
    state_top10 = pickle.load(f)
f.close()
for (i,s) in enumerate(state_top10):
    state_top10[i] = state_top10[i].replace('"','')
    state_top10[i] = state_top10[i].replace('[','')
    state_top10[i] = state_top10[i].replace(']','')

# reading top 10 reasons
with open('top10reason.dat') as f:
    state_reason_top10 = pickle.load(f)
f.close()
    
feature_all = []
state_all = []
state_fsq_all = []
state_reason_all = []
for filename in files:
    with open(ft_dir+filename) as f:  
        feature, state, state_fsq, state_reason, feature_label_ = pickle.load(f)

        # only keeping top 10 states
        ind = np.array([], int)
        for (i,st) in enumerate(state):
            if st in state_top10:
                ind = np.append(ind, i)
        feature = feature[ind,:]
        state = state[ind]
        state_fsq = state_fsq[ind]
        state_reason = state_reason[ind]
        
        # only keeping top 10 reasons
        ind = np.array([], int)
        for (i,st) in enumerate(state_reason):
            if st in state_reason_top10:
                ind = np.append(ind, i)
        feature = feature[ind,:]
        state = state[ind]
        state_fsq = state_fsq[ind]
        state_reason = state_reason[ind]

        feature_all.append(feature)
        state_all.append(state)
        state_fsq_all.append(state_fsq)
        state_reason_all.append(state_reason)
        
    f.close()

confs = []
aucs = []
labels = []
confs_fsq = []
aucs_fsq = []

for i in range(len(feature_all)):
    
    #t0 = time.time()
    print '------------------'
    print i
    if i==6:
        print 'subject skipped because of lack of data'
        continue
    
    # training set
    j_range = range(len(feature_all))
    j_range.pop(i)
    x_train = np.concatenate([feature_all[j] for j in j_range], axis=0)
    #y_train = np.concatenate([state_all[j] for j in j_range])
    y_train = np.concatenate([state_reason_all[j] for j in j_range])
    #t1 = time.time()
    
    if do_stratify:
        x_train, y_train = stratify(x_train,y_train)
    
    # test set
    x_test = feature_all[i]
    #y_test = state_all[i]
    y_test = state_reason_all[i]
    #t2 = time.time()
    
    # training (layer 1)
    #eta_list = np.array([0.05]*200+[0.02]*200+[0.01]*200)
    gbm = xgb.XGBClassifier(max_depth=3, n_estimators=100, learning_rate=0.01, nthread=12, subsample=1,\
                               max_delta_step=0).fit(x_train, y_train)
    
    # training (later 2)
#     x_train_post = gbm.predict_proba(x_train)
#     gbm2 = xgboost.XGBClassifier(max_depth=3, n_estimators=30, learning_rate=0.05, nthread=12, subsample=1,\
#                                max_delta_step=0).fit(x_train_post, y_train)
    
    # test
    y_pred = gbm.predict(x_test) # first layer
    
#     x_test_post = gbm.predict_proba(x_test)
#     y_pred = gbm2.predict(x_test_post) # 2 layer prediction
    
    #t3 = time.time()
    
    # confusion matrix, AUC
    conf, roc_auc = calculate_confusion_matrix(y_pred, y_test)
    #t4 = time.time()
    
    # confusion matrix, AUC for foursquare
    #conf_fsq, roc_auc_fsq = calculate_confusion_matrix(state_fsq_all[i], y_test)
    
    #print t1-t0, t2-t1, t3-t2, t4-t3
    print np.unique(y_test)
    #print conf
    print 'model:'
    print roc_auc
    #print 'foursquare:'
    #print roc_auc_fsq
    labels.append(np.unique(y_test))
    confs.append(conf)
    aucs.append(roc_auc)
    #confs_fsq.append(conf_fsq)
    #aucs_fsq.append(roc_auc_fsq)
    
# saving the results
if save_results:
    with open('accuracy_reason_100_d3.dat','w') as f:
        #pickle.dump([aucs, confs, labels, aucs_fsq, confs_fsq], f)
        pickle.dump([aucs, confs, labels], f)
    f.close()
# Out:
# ------------------
# 0
# ['Dining,Socialize' 'Errand' 'Home' 'Socialize']
# model:
# [        nan  0.83099415  1.          0.95967742]
# ------------------
# 1
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Travelling/Traffic' 'Work']
# model:
# [ 0.68833333         nan         nan  0.57142857  0.94690171  0.72286822
#          nan  0.92766777]
# ------------------
# 2
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Exercise' 'Home'
#  'Work']
# model:
# [ 0.63780664         nan  0.48571429  0.68640351         nan  0.77868852
#   0.57833333]
# ------------------
# 3
# ['Dining' 'Entertainment,Socialize' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.61925287         nan  0.74438202  0.97115385  0.73314607  0.90994624]
# ------------------
# 4
# ['Errand' 'Home' 'Socialize']
# model:
# [ 0.87121212  1.                 nan]
# ------------------
# 5
# ['Dining' 'Entertainment' 'Home' 'Socialize' 'Work']
# model:
# [ 0.49367089         nan  0.98837209         nan  0.859375  ]
# ------------------
# 6
# subject skipped because of lack of data
# ------------------
# 7
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.64308176  0.63510638  0.69607843  0.69777778  0.68270042]
# ------------------
# 8
# ['Dining,Socialize' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [        nan  0.95371857  0.92241379  0.73148148  0.87731134]
# ------------------
# 9
# ['Dining' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.95967742  0.77284105  1.                 nan]
# ------------------
# 10
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Work']
# model:
# [ 0.57468354         nan         nan  0.84285714  0.93152542  0.80454545]
# ------------------
# 11
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.86956522         nan  0.71411554  0.96112412  0.49473684]
# ------------------
# 12
# ['Dining' 'Dining,Socialize' 'Errand' 'Socialize']
# model:
# [ 0.57142857         nan  0.63636364  0.88709677]
# ------------------
# 13
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.79203297         nan  0.86052632  0.96939124  0.62037037  0.4950495 ]
# ------------------
# 14
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.66586074         nan         nan         nan  0.82083739  0.96511628
#   0.9950495   0.94642857]
# ------------------
# 15
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/ranking.py:530: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   UndefinedMetricWarning)
# ['Dining' 'Errand' 'Home' 'Socialize']
# model:
# [ nan  nan  nan  nan]
# ------------------
# 16
# ['Dining' 'Errand']
# model:
# [ 0.55432373  0.41917293]
# ------------------
# 17
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Work']
# model:
# [ 0.66183943         nan         nan  0.65903308  0.97263418  0.81030702
#   0.760765  ]
# ------------------
# 18
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Work']
# model:
# [ 0.65846995         nan         nan  0.89565217  0.99074074  0.93395707]
# ------------------
# 19
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Work']
# model:
# [ 0.98850575         nan  0.83358974  0.98913043  0.87800963]
# ------------------
# 20
# ['Dining' 'Entertainment' 'Errand' 'Exercise' 'Home' 'Socialize' 'Work']
# model:
# [ 0.75672515         nan  0.6413117          nan  0.98913043  0.93203883
#   0.90322581]
# ------------------
# 21
# ['Dining' 'Errand' 'Exercise' 'Home' 'Work']
# model:
# [ 0.70362473  0.84481203         nan  0.94029851  0.63417131]
# ------------------
# 22
# ['Dining' 'Errand' 'Home']
# model:
# [ 0.66666667  0.66666667  1.        ]
# ------------------
# 23
# ['Dining' 'Entertainment' 'Errand' 'Exercise' 'Socialize' 'Work']
# model:
# [ 0.9673913          nan  0.53869048         nan  0.69565217  0.82291667]
# ------------------
# 24
# ['Dining' 'Dining,Socialize' 'Home' 'Socialize']
# model:
# [ 0.4                nan  0.98913043  0.94776119]
# ------------------
# 25
# ['Dining' 'Errand' 'Home' 'Work']
# model:
# [ 0.52747253  0.54159495  0.75343228  0.52097378]
# ------------------
# 26
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.625       0.93736842  0.97222222  0.97761194  0.97540984]
# ------------------
# 27
# ['Dining' 'Entertainment' 'Home']
# model:
# [ nan   1.   1.]
# ------------------
# 28
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.66198126  0.49425287  0.68787879  0.89213233  0.57741617  0.79138292]
# ------------------
# 29
# ['Dining' 'Errand' 'Home' 'Work']
# model:
# [ 0.66666667  0.69166667  0.3125      0.44444444]
# ------------------
# 30
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize']
# model:
# [ 0.75               nan         nan  0.87475198  0.98837209         nan]
# ------------------
# 31
# ['Errand' 'Home']
# model:
# [ nan   1.]
# ------------------
# 32
# ['Errand' 'Home' 'Socialize']
# model:
# [ 0.97368421  1.                 nan]
# ------------------
# 33
# ['Errand' 'Exercise' 'Home' 'Socialize']
# model:
# [ 0.88235294         nan  0.99074074  0.94666667]
# ------------------
# 34
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize'
#  'Work']
# model:
# [ 0.72787611  0.49593496  0.87086777  0.77153558  0.96106219  0.5952381
#   0.78947368]
# ------------------
# 35
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.74115044         nan  0.56194969  0.93188668  0.90833333  0.76806904]
# ------------------
# 36
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize'
#  'Travelling/Traffic' 'Work']
# model:
# [ 0.85576923         nan  0.97142857  0.67572634  0.82380779  0.49056604
#          nan  0.87234043]
# ------------------
# 37
# ['Dining,Socialize' 'Errand' 'Home' 'Travelling/Traffic']
# model:
# [        nan  0.77777778  0.80555556         nan]
# ------------------
# 38
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.76177536  0.66666667  0.98484848  0.79954955  0.71575342]
# ------------------
# 39
# ['Dining' 'Home']
# model:
# [ 1.  1.]
# ------------------
# 40
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize'
#  'Work']
# model:
# [ 0.69022869         nan  0.74681529  0.71388578  0.87944215  0.60654886
#   0.63490676]
# ------------------
# 41
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Travelling/Traffic' 'Work']
# model:
# [ 0.4924812          nan         nan  0.60484813  0.88968254  0.70925926
#          nan  0.74101655]
# ------------------
# 42
# ['Dining' 'Entertainment' 'Entertainment,Socialize' 'Exercise' 'Home'
#  'Socialize']
# model:
# [ nan  nan  nan  nan  nan  nan]
# ------------------
# 43
# ['Dining' 'Entertainment' 'Entertainment,Socialize' 'Errand' 'Exercise'
#  'Home' 'Socialize' 'Work']
# model:
# [ 0.60444874         nan         nan  0.55595238         nan  0.49074074
#   0.65705128  0.65873016]
# ------------------
# 44
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Socialize'
#  'Travelling/Traffic']
# model:
# [ 0.63888889         nan  0.484375    0.56818182  0.6                nan]
# ------------------
# 45
# ['Entertainment' 'Errand' 'Home']
# model:
# [        nan  0.40909091  1.        ]
# ------------------
# 46
# ['Dining' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.92087912  0.88653846  0.89375            nan]
# ------------------
# 47
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize'
#  'Travelling/Traffic' 'Work']
# model:
# [ 0.80141844         nan  0.48076923  0.75        0.92592593         nan
#          nan  0.90692641]
# ------------------
# 48
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.73901099  0.80917281  0.98214286  0.7450495   0.82857143]
# ------------------
# 49
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.51904762         nan  0.49593496         nan  0.66931919  0.95371397
#   0.94166667  0.75595643]
# ------------------
# 50
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.61842105         nan  0.78067797  1.          0.88101266]
# ------------------
# 51
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Home' 'Socialize' 'Work']
# model:
# [ 0.48507463         nan         nan  1.          0.76410256  0.49206349]
# ------------------
# 52
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.48701299         nan  0.93478261  0.984375    0.81434599]
# ------------------
# 53
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize' 'Travelling/Traffic' 'Work']
# model:
# [ 0.61944444         nan  0.98969072         nan  0.92857143  0.90027574
#   0.59773756         nan  0.48214286]
# ------------------
# 54
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Work']
# model:
# [ 0.68416667         nan  0.82302329  0.99596774  0.40184049]
# ------------------
# 55
# ['Dining' 'Errand' 'Home' 'Work']
# model:
# [        nan  0.66935484  0.8543956   0.78396872]
# ------------------
# 56
# ['Dining' 'Dining,Socialize' 'Errand' 'Home']
# model:
# [ 0.64583333         nan  0.6474359   1.        ]
# ------------------
# 57
# ['Dining' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.75714286  0.86800289  0.99107143  0.86556604]
# ------------------
# 58
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.65988701         nan  0.67104262  0.72019406  0.49723757]
# ------------------
# 59
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.69367089         nan  0.9015625   1.          0.7195122 ]
# ------------------
# 60
# ['Errand' 'Home']
# model:
# [ 0.99107143  1.        ]
# ------------------
# 61
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.9453125          nan  0.46666667  0.98958333  0.59193548  0.60912698]
# ------------------
# 62
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Work']
# model:
# [ 0.8034188          nan         nan  0.93105159  0.96478873  0.94736842]
# ------------------
# 63
# ['Dining' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.92708333  0.66666667  0.96153846         nan]
# ------------------
# 64
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.4985119          nan         nan         nan  0.74921289  0.74259806
#   0.4968652   0.73312758]
# ------------------
# 65
# ['Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.99390244  0.99019608  0.99404762  0.97383005]
# ------------------
# 66
# ['Errand' 'Home' 'Work']
# model:
# [ 0.66666667  1.          0.88461538]
# ------------------
# 67
# ['Dining' 'Entertainment' 'Errand' 'Exercise' 'Home' 'Socialize'
#  'Travelling/Traffic' 'Work']
# model:
# [ 0.53490909         nan  0.69607183         nan  0.946875    0.49102564
#          nan  0.54166667]
# ------------------
# 68
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Travelling/Traffic'
#  'Work']
# model:
# [ 0.53989704  0.98230088  0.74335106  0.83835616  0.4826087          nan
#   0.80287115]
# ------------------
# 69
# ['Dining' 'Entertainment' 'Errand' 'Exercise' 'Home' 'Socialize' 'Work']
# model:
# [ 0.69945521         nan  0.77698925         nan  0.9747962   0.76875
#   0.62774295]
# ------------------
# 70
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize']
# model:
# [        nan         nan         nan         nan  0.58333333  0.83333333
#   0.92857143]
# ------------------
# 71
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.82566845         nan  0.70995228  0.96969001  0.57164948  0.89739709]
# ------------------
# 72
# ['Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.83788707  0.93396226  0.98717949  0.49324324]
# ------------------
# 73
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.75               nan         nan         nan  0.70175439  0.87962963
#   0.48734177  0.82119004]
# ------------------
# 74
# ['Home']
# model:
# [ 0.5]
# ------------------
# 75
# ['Dining' 'Entertainment' 'Errand' 'Home']
# model:
# [ 0.74166667  0.97580645  0.89583333  1.        ]
# ------------------
# 76
# ['Dining' 'Work']
# model:
# [ 0.45454545         nan]
# ------------------
# 77
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize'
#  'Work']
# model:
# [ 1.                 nan  1.          0.85        0.75576184  0.82777778
#   0.35      ]
# ------------------
# 78
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize'
#  'Travelling/Traffic' 'Work']
# model:
# [ 0.52476489         nan  0.6503268   0.82754717  1.          0.47712418
#          nan  0.85736998]
# ------------------
# 79
# ['Dining,Socialize' 'Errand' 'Home' 'Socialize']
# model:
# [        nan  0.85230352  0.82780488  0.78651685]
# ------------------
# 80
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Exercise' 'Home'
#  'Socialize' 'Work']
# model:
# [ 0.83642344         nan  0.98113208  0.57142857         nan  0.8517316
#   0.79967949  0.60047847]
# ------------------
# 81
# ['Dining' 'Errand' 'Home' 'Work']
# model:
# [        nan  0.92857143  0.95238095  0.96428571]
# ------------------
# 82
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [        nan  0.94642857  1.          0.79411765  0.71428571]
# ------------------
# 83
# ['Errand' 'Home' 'Socialize']
# model:
# [ 0.75  1.     nan]
# ------------------
# 84
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home']
# model:
# [ 0.66064257         nan         nan  0.82708333  0.95      ]
# ------------------
# 85
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.6                nan         nan  0.52307692  0.82352941  0.43333333]
# ------------------
# 86
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Work']
# model:
# [ 0.57448378         nan         nan  0.83220109  0.89208119  0.86734694]
# ------------------
# 87
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 1.                 nan  0.90384615  0.9893617   0.98611111  0.97138799]
# ------------------
# 88
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Exercise'
#  'Socialize' 'Work']
# model:
# [ 0.65384615         nan  1.          0.71216931         nan  0.56289308
#   0.89      ]
# ------------------
# 89
# ['Dining' 'Entertainment' 'Entertainment,Socialize' 'Errand' 'Socialize'
#  'Work']
# model:
# [ 0.61538462  0.82291667         nan  0.70833333  0.94        0.71875   ]
# ------------------
# 90
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.65868012  0.80570652  0.88761716  0.73972603  0.79356928]
# ------------------
# 91
# ['Errand' 'Exercise' 'Home' 'Socialize' 'Work']
# model:
# [ 0.78913043         nan  0.93243243         nan  0.94186047]
# ------------------
# 92
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize']
# model:
# [ 0.48666667         nan  0.48666667         nan  0.86874237  0.94949495
#   0.48630137]
# ------------------
# 93
# ['Dining' 'Errand' 'Exercise' 'Home' 'Socialize' 'Work']
# model:
# [ 0.66358025  0.69659515         nan  0.81960979  0.83026585  0.61791133]
# ------------------
# 94
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.66666667         nan  0.74107143  0.82534562  0.84488189  0.74813896]
# ------------------
# 95
# ['Entertainment' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.49557522  0.53947368  0.54448529  0.54806409  0.45694444]
# ------------------
# 96
# ['Errand' 'Home' 'Socialize']
# model:
# [ 0.7         1.          0.95454545]
# ------------------
# 97
# ['Dining' 'Entertainment' 'Errand' 'Home']
# model:
# [ 0.46296296  0.98076923  0.64393939  0.94444444]
# ------------------
# 98
# ['Dining' 'Errand' 'Home' 'Work']
# model:
# [ 0.98863636  0.91017316  0.98837209  0.98275862]
# ------------------
# 99
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.49431818         nan  0.91142857  0.92931346  0.81456044  0.6       ]
# ------------------
# 100
# ['Dining' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.45454545  0.65238095  1.          0.73888889]
# ------------------
# 101
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.61111111         nan         nan         nan  0.75534188  0.53321678
#   0.49404762  0.63762315]
# ------------------
# 102
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Work']
# model:
# [ 0.68840144         nan  0.63043478         nan  0.73960499  0.99
#   0.9768711 ]
# ------------------
# 103
# ['Dining' 'Errand' 'Socialize' 'Work']
# model:
# [ 0.65737515  0.55949657  0.54492754  0.53861193]
# ------------------
# 104
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.69230769  0.84572697  0.79073615  0.49230769  0.64655172]
# ------------------
# 105
# ['Dining' 'Entertainment' 'Home' 'Travelling/Traffic' 'Work']
# model:
# [ 0.98850575         nan  0.99               nan  0.95120614]
# ------------------
# 106
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Home' 'Socialize' 'Work']
# model:
# [ 0.65876437         nan         nan  0.84615385  0.48404255  0.53354978]
# ------------------
# 107
# ['Errand' 'Home']
# model:
# [        nan  0.44047619]
# ------------------
# 108
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Work']
# model:
# [ 0.61255411         nan         nan  0.71542429  0.96078431  0.71634615
#   0.93813131]
# ------------------
# 109
# ['Dining' 'Home' 'Work']
# model:
# [ 1.  1.  1.]
# ------------------
# 110
# ['Errand' 'Home' 'Socialize']
# model:
# [ 0.96875     0.97222222  0.99568966]
# ------------------
# 111
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize']
# model:
# [ 0.6331484          nan  0.49541284         nan  0.90740741  0.99056604
#   0.98695652]
# ------------------
# 112
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Work']
# model:
# [ 0.59281843         nan         nan  0.68039216  0.92715054  0.6994382
#   0.61178862]
# ------------------
# 113
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize' 'Travelling/Traffic']
# model:
# [ 0.73837209         nan  0.99473684         nan  0.79193698  0.80254498
#   0.75054945         nan]
# ------------------
# 114
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Travelling/Traffic'
#  'Work']
# model:
# [ 0.64936709         nan  0.81606673  0.95945946         nan         nan
#   0.73333333]
# ------------------
# 115
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Exercise' 'Home' 'Socialize' 'Work']
# model:
# [ 0.58333333         nan  0.49122807         nan  0.65697674         nan
#   0.525       0.44736842  0.68543956]
# ------------------
# 116
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Exercise' 'Home'
#  'Socialize']
# model:
# [ 0.88333333         nan  1.          0.56024531         nan  0.9309867
#   0.90361446]
# ------------------
# 117
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Travelling/Traffic'
#  'Work']
# model:
# [ 0.57180851  0.49342105  0.64922481  0.78732517  0.53125            nan
#   0.69939467]
# ------------------
# 118
# ['Dining' 'Errand' 'Exercise' 'Home' 'Socialize' 'Work']
# model:
# [ 0.97674419  0.65               nan  1.          0.66666667         nan]
# ------------------
# 119
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.73255814  0.88473684  0.56666667  0.48275862  0.81818182]
# ------------------
# 120
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.77246377  0.88979592  0.98203957  0.625       0.84178744]
# ------------------
# 121
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.55208333  0.53018645  0.82738095  0.64179104  0.65566038]
# ------------------
# 122
# ['Dining' 'Errand' 'Home' 'Socialize' 'Travelling/Traffic']
# model:
# [ 0.74074074  0.48611111  0.70470588  0.69230769         nan]
# ------------------
# 123
# ['Dining' 'Entertainment' 'Errand' 'Home']
# model:
# [ 1.          0.99275362  0.95        0.97727273]
# ------------------
# 124
# ['Dining' 'Errand' 'Home']
# model:
# [ 0.77802198  0.94677871  1.        ]
# ------------------
# 125
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.75945946         nan  0.74230769  1.          0.96153846]
# ------------------
# 126
# ['Dining' 'Errand' 'Exercise' 'Home' 'Socialize' 'Work']
# model:
# [ 0.61538462  0.4375             nan  0.48076923         nan  0.67407407]
# ------------------
# 127
# ['Errand' 'Socialize']
# model:
# [ 0.75        0.63636364]
# ------------------
# 128
# ['Dining,Socialize' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [        nan  0.58272907  0.98979592  0.98684211  0.29605263]
# ------------------
# 129
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.65384615         nan  0.62747036  1.          0.6547619   0.34090909]
# ------------------
# 130
# ['Dining' 'Errand' 'Home' 'Work']
# model:
# [ 0.74065421  0.77777778  0.95459184  0.92270531]
# ------------------
# 131
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Work']
# model:
# [ 0.79060219         nan         nan  0.89111498  0.92367865  0.44666667
#   0.79111068]
# ------------------
# 132
# ['Dining,Socialize' 'Entertainment' 'Entertainment,Socialize' 'Errand'
#  'Home' 'Socialize' 'Work']
# model:
# [        nan  1.                 nan  0.86216931  1.                 nan
#   0.49431818]
# ------------------
# 133
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.73587571         nan  0.53110795  0.51907407  0.7325419   0.60790274]
# ------------------
# 134
# ['Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.73170732  1.          0.46938776  0.97297297]
# ------------------
# 135
# ['Dining' 'Home' 'Work']
# model:
# [ 0.89130435  0.90909091  0.43478261]
# ------------------
# 136
# ['Dining' 'Errand' 'Exercise' 'Home']
# model:
# [        nan  0.66666667         nan  1.        ]
# ------------------
# 137
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.49390244         nan  0.91446541  1.          0.75        0.48780488]
# ------------------
# 138
# ['Dining' 'Errand' 'Home']
# model:
# [  nan  0.65  0.9 ]
# ------------------
# 139
# ['Dining' 'Entertainment' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Work']
# model:
# [ 0.89411765         nan         nan  0.69952867  0.86979167  0.62916667
#   0.58928571]
# ------------------
# 140
# ['Dining' 'Entertainment' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Work']
# model:
# [ 0.48684211  0.48809524         nan  0.67810458  0.51547619  0.56052632
#   0.60357143]
# ------------------
# 141
# ['Errand' 'Home']
# model:
# [ 1.          0.83333333]
# ------------------
# 142
# ['Dining' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.91218638  0.87803644  1.          0.97      ]
# ------------------
# 143
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize'
#  'Work']
# model:
# [ 0.66051587         nan  0.92286585  0.7489605   0.94924242  0.57115385
#   0.7213868 ]
# ------------------
# 144
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Work']
# model:
# [ 0.7                nan  0.97761194  0.96650327  0.93193548]
# ------------------
# 145
# ROC AUC set to nan due to lack of data
# ['Home']
# model:
# [ nan]
# ------------------
# 146
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize'
#  'Work']
# model:
# [ 0.81315789         nan         nan  0.64117647  0.91783346  0.575
#   0.80864198]
# ------------------
# 147
# ['Entertainment' 'Errand' 'Work']
# model:
# [ 0.75        0.8891129   0.79076087]
# ------------------
# 148
# ['Dining' 'Home']
# model:
# [       nan  0.4765625]
# ------------------
# 149
# ['Dining' 'Entertainment' 'Errand' 'Socialize' 'Work']
# model:
# [ 0.80588235  0.84305835  0.56980519  0.71428571  0.80471499]
# ------------------
# 150
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.97540984  0.66931818  0.8891129          nan  0.71341463]
# ------------------
# 151
# ['Dining' 'Entertainment' 'Errand' 'Home']
# model:
# [ 0.85576923  0.96470588  0.78729753  1.        ]
# ------------------
# 152
# ['Entertainment' 'Home']
# model:
# [        nan  0.41666667]
# ------------------
# 153
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.71345029         nan         nan  0.88965885  0.97625     0.61659664]
# ------------------
# 154
# ['Dining' 'Errand' 'Exercise' 'Socialize']
# model:
# [  nan  0.05   nan   nan]
# ------------------
# 155
# ['Dining' 'Entertainment' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize']
# model:
# [ 0.77282728         nan         nan  0.72294814  1.          0.90865385]
# ------------------
# 156
# ['Dining' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.66171617  0.95215402  0.99122807         nan]
# ------------------
# 157
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.65614035         nan  0.72508741  0.9072327          nan  0.83055312]
# ------------------
# 158
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.81333333         nan  0.89583333  0.84313725         nan  0.88717949]
# ------------------
# 159
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Travelling/Traffic'
#  'Work']
# model:
# [ 0.60895141         nan  0.83035714  0.91902439  0.4921875          nan
#   0.61538462]
# ------------------
# 160
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Exercise' 'Home' 'Socialize' 'Travelling/Traffic' 'Work']
# model:
# [ 0.59639465         nan  0.49765258         nan  0.62436647         nan
#   0.72100122  0.51737757         nan  0.66497976]
# ------------------
# 161
# ['Errand' 'Home' 'Socialize']
# model:
# [ 0.98148148  1.          0.67307692]
# ------------------
# 162
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Work']
# model:
# [ 0.59840426         nan         nan  0.8030303   0.98837209  0.58295455
#   0.78472222]
# ------------------
# 163
# ['Dining' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.8         0.85784314         nan         nan]
# ------------------
# 164
# ['Dining' 'Entertainment' 'Errand' 'Exercise' 'Home' 'Socialize' 'Work']
# model:
# [ 0.77469014  0.57721713  0.71519608  0.49849398  0.97093718  0.48006135
#   0.4718543 ]
# ------------------
# 165
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.87687688  0.98031496  0.76560939  0.99019608  0.98818898]
# ------------------
# 166
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.52252747         nan         nan  0.83572635  1.          0.43939394]
# ------------------
# 167
# ['Dining' 'Errand' 'Work']
# model:
# [ 0.83333333  0.84615385  0.47222222]
# ------------------
# 168
# ['Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.96052632  1.          0.47826087  0.625     ]
# ------------------
# 169
# ROC AUC set to nan due to lack of data
# ['Home']
# model:
# [ nan]
# ------------------
# 170
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize'
#  'Work']
# model:
# [ 0.95882353         nan         nan  0.65789474  0.98717949  0.48235294
#   0.99295775]
# ------------------
# 171
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.57389937  0.75333333  0.80497685  0.46551724  0.73110465]
# ------------------
# 172
# ['Dining' 'Dining,Socialize' 'Errand' 'Exercise' 'Home' 'Socialize' 'Work']
# model:
# [ 0.69565217         nan  0.5625             nan  0.50833333  1.
#   0.32065217]
# ------------------
# 173
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Socialize'
#  'Work']
# model:
# [ 0.69082569         nan  0.96788991  0.71978236  0.83636364  0.99115044
#   0.4950495 ]
# ------------------
# 174
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.4893617          nan  0.525       0.96837895  0.48333333  0.89473684]
# ------------------
# 175
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 1.                 nan  0.99107143  1.          0.66666667  1.        ]
# ------------------
# 176
# ['Errand' 'Home']
# model:
# [ 0.94444444  0.94444444]
# ------------------
# 177
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize']
# model:
# [ 0.5962406          nan  0.9858156          nan  0.74586514  0.96848073
#   0.78690476]
# ------------------
# 178
# ['Dining' 'Errand' 'Exercise' 'Home' 'Socialize' 'Travelling/Traffic'
#  'Work']
# model:
# [ 0.76027749  0.6962963          nan  0.87693118  0.76174168         nan
#   0.54163775]
# ------------------
# 179
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Errand' 'Home' 'Work']
# model:
# [ 0.6625             nan  0.99596774  0.87021531  0.96753247  0.94583333]
# ------------------
# 180
# ['Dining' 'Errand' 'Exercise' 'Home' 'Socialize' 'Work']
# model:
# [ 0.98809524  0.82352941         nan  0.98648649  0.98125     0.93308424]
# ------------------
# 181
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.53382664         nan  0.59009217  0.51315789  0.53441011  0.40869565]
# ------------------
# 182
# ['Dining' 'Dining,Socialize' 'Errand' 'Exercise' 'Home' 'Socialize' 'Work']
# model:
# [ 0.66666667         nan  0.94059829         nan  0.90277778  0.86354962
#   0.90263645]
# ------------------
# 183
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.8         0.63636364  0.87424242  0.46721311  0.63125   ]
# ------------------
# 184
# ['Dining' 'Home' 'Socialize' 'Travelling/Traffic']
# model:
# [ 0.57142857  0.76704545  0.36486486         nan]
# ------------------
# 185
# ['Dining' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.97413793  0.73623853  0.95614035  0.43965517  0.85009058]
# ------------------
# 186
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.7                nan  0.82857143  0.94760101  0.72807018  0.88505747]
# ------------------
# 187
# ['Dining' 'Home' 'Socialize' 'Work']
# model:
# [ 0.84109477  0.89817416  0.68928571  0.87524291]
# ------------------
# 188
# ['Dining' 'Errand' 'Socialize' 'Work']
# model:
# [ 0.82638889  0.78055556  0.73648649  0.73397436]
# ------------------
# 189
# ['Dining' 'Entertainment' 'Errand' 'Home']
# model:
# [ 0.46153846         nan  0.95918367  0.93333333]
# ------------------
# 190
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Home' 'Work']
# model:
# [ 0.75               nan         nan  0.98387097  0.94938776]
# ------------------
# 191
# ['Dining' 'Dining,Socialize' 'Errand' 'Home' 'Travelling/Traffic']
# model:
# [ 0.57142857         nan  0.92927632  0.97916667         nan]
# ------------------
# 192
# ['Dining' 'Errand' 'Home']
# model:
# [ 0.75        0.98275862  1.        ]
# ------------------
# 193
# ['Entertainment' 'Errand' 'Home']
# model:
# [        nan  0.97826087  1.        ]
# ------------------
# 194
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Work']
# model:
# [ 0.57878788         nan         nan  0.78901099  0.96226415  0.70089286
#   0.89617145]
# ------------------
# 195
# ['Dining' 'Errand' 'Exercise' 'Home' 'Socialize']
# model:
# [ 0.48571429  0.68817204         nan  0.46666667  0.74509804]
# ------------------
# 196
# ['Dining' 'Entertainment' 'Home' 'Socialize' 'Work']
# model:
# [ 0.67344173         nan  0.94428295  0.81568627  0.8801054 ]
# ------------------
# 197
# ['Dining' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.99029126  0.91996951  0.97916667         nan]
# ------------------
# 198
# ['Dining' 'Dining,Socialize' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Work']
# model:
# [ 1.                 nan         nan  0.76968085  1.          0.60681818
#   0.97761194]
# ------------------
# 199
# ['Dining' 'Entertainment' 'Errand' 'Home' 'Socialize']
# model:
# [ 0.60688759  0.46969697  0.67100694  0.90364583  0.48469388]
# ------------------
# 200
# ['Dining' 'Errand' 'Home']
# model:
# [ 0.75        0.78846154  0.80434783]
# ------------------
# 201
# ['Dining' 'Errand' 'Exercise' 'Home' 'Socialize']
# model:
# [ 0.66666667  0.67916667         nan  0.47916667  0.12962963]
# ------------------
# 202
# ['Dining' 'Entertainment' 'Entertainment,Socialize' 'Errand' 'Home'
#  'Socialize' 'Work']
# model:
# [ 0.88736264         nan         nan  0.86737401  0.90327696  0.74473684
#   0.93798077]
# ------------------
# 203
# ['Dining' 'Dining,Socialize' 'Entertainment' 'Entertainment,Socialize'
#  'Errand' 'Home' 'Socialize' 'Work']
# model:
# [ 0.45625            nan         nan         nan  0.54166667  0.74902153
#   0.78170732  0.51288937]

# %%
len(state_reason_all[0])
# Out:
# 64
