# %%
import os
import pickle
import pandas as pd
import numpy as np
import xgboost as xgb
from calculate_confusion_matrix import calculate_confusion_matrix
import time
from copy import deepcopy
from utils import one_hot_encoder
# from sklearn.preprocessing import OneHotEncoder
# from sklearn import preprocessing

save_results = True

n_boot = 100
split = 0.7
np.random.seed(seed=0)

ft_dir = 'features_long/'

# list feature files
files = os.listdir(ft_dir)

# reading top locations
with open('top_locations.dat','rb') as f:
    location_top = pickle.load(f)
f.close()

target_all = []
for filename in files:
    with open(ft_dir+filename, 'rb') as f:  
        _, target = pickle.load(f)

        # only keeping top locations
        ind = np.array([], int)
        for (i,loc) in enumerate(target['location']):
            if loc in location_top:
                ind = np.append(ind, i)
        target = target.loc[ind]
        target = target.reset_index(drop=True)
        
        target_all.append(target)
        
    f.close()

confs = []
aucs = []
labels = []
inds = np.arange(0,len(target_all),1)

for i in range(n_boot):
    
    print('------------------')
    print(i)
    
#     ind_boot = np.random.choice(inds, size=inds.size, replace=True)
    ind_boot = np.random.choice(inds, size=inds.size-int(np.floor(inds.size*split)), replace=False)
    
    y_report = pd.concat([target_all[j]['location'] for j in ind_boot], axis=0)
    y_fsq = pd.concat([target_all[j]['fsq'] for j in ind_boot], axis=0)
    
    # foursquare performance
    conf, roc_auc = calculate_confusion_matrix(y_fsq, y_report)
    
    labels.append(np.unique(y_report))
    confs.append(conf)
    aucs.append(roc_auc)

    print(np.unique(y_report))
    print(roc_auc, np.nanmean(roc_auc))
    
if save_results:
    with open('auc_location_new_10fold_fsq3.dat','wb') as f:
        pickle.dump([aucs, confs, labels], f)
    f.close()
# Out:
# ------------------
# 0
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.55988768  0.63424298  0.72349414  0.54240931  0.50543778
#   0.57175766  0.73528812         nan  0.50644515         nan] 0.597370353203
# ------------------
# 1
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61685297  0.66502325  0.63558651  0.64432614  0.50819295
#   0.53772039  0.73320579         nan  0.527384           nan] 0.608536499739
# ------------------
# 2
# /usr/local/lib/python3.4/dist-packages/sklearn/metrics/ranking.py:542: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61252782  0.6584663   0.68719191  0.54680955  0.50690401
#   0.55350519  0.71497639         nan  0.51170961         nan] 0.599011347341
# ------------------
# 3
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58392128  0.65003152  0.70879014  0.57777131  0.50299869
#   0.54102939  0.72781031         nan  0.50077654         nan] 0.599141149269
# ------------------
# 4
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58914634  0.69489328  0.74276841  0.55014554  0.50964869
#   0.56142322  0.70262487         nan  0.51019652         nan] 0.60760585764
# ------------------
# 5
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.5891729   0.67532283  0.73455043  0.58110579  0.5020448
#   0.53199937  0.7312029          nan  0.51816408         nan] 0.607945388095
# ------------------
# 6
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58528752  0.63124271  0.6536859   0.55702305  0.50188121
#   0.53136869  0.72707718         nan  0.51465718         nan] 0.587777929161
# ------------------
# 7
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.60486722  0.65661043  0.62140148  0.53358789  0.50833551
#   0.55720753  0.69243416         nan  0.50601295         nan] 0.585057147711
# ------------------
# 8
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.59874212  0.66989157  0.71631101  0.56819043  0.50418396
#   0.57510193  0.74447342         nan  0.5003806          nan] 0.60965937773
# ------------------
# 9
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.59680648  0.64379768  0.63165249  0.5485247   0.50334166
#   0.56036817  0.7583009          nan  0.50451011         nan] 0.593412775153
# ------------------
# 10
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61354589  0.67139823  0.77697277  0.56322325  0.50686788
#   0.55169574  0.70130076         nan  0.50512465         nan] 0.611266145096
# ------------------
# 11
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.65433934  0.72835961  0.73982761  0.61420266  0.50676935
#   0.54101366  0.69422079         nan  0.51837731         nan] 0.624638789603
# ------------------
# 12
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.63087526  0.68507111  0.74973935  0.56794182  0.50645343
#   0.56086826  0.70289754         nan  0.51492135         nan] 0.614846014785
# ------------------
# 13
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.59910154  0.64030885  0.74935011  0.52920936  0.5042482
#   0.56819183  0.71725035         nan  0.55309155         nan] 0.607593976339
# ------------------
# 14
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.63822238  0.62651986  0.69858978  0.57064765  0.50706716
#   0.55150696  0.69938897         nan  0.5046575          nan] 0.599575031367
# ------------------
# 15
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61319823  0.6532329   0.74614632  0.58659188  0.5057572
#   0.54797096  0.75191566         nan  0.52144451         nan] 0.615782205609
# ------------------
# 16
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.5616178   0.59553885  0.70790343  0.52079654  0.5105043
#   0.54602911  0.68434894         nan  0.50236041         nan] 0.578637423356
# ------------------
# 17
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.60796126  0.65002576  0.71486244  0.60816461  0.50853537
#   0.55699622  0.78261491         nan  0.54438725         nan] 0.621693479183
# ------------------
# 18
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.64443375  0.6371066   0.72845635  0.61357484  0.51179302
#   0.53026841  0.68762864         nan  0.50773991         nan] 0.607625189187
# ------------------
# 19
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57689729  0.62883888  0.71870031  0.66580636  0.5078444
#   0.54704034  0.70177503         nan  0.50357695         nan] 0.606309944537
# ------------------
# 20
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.70885392  0.65364689  0.69138234  0.58950118  0.5068635
#   0.54820301  0.73972429         nan  0.50925896         nan] 0.618429261636
# ------------------
# 21
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.6244056   0.67209065  0.70337574  0.58370495  0.50765501
#   0.53788495  0.72603904         nan  0.50346313         nan] 0.607327383535
# ------------------
# 22
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57634409  0.6309632   0.60831396  0.54700991  0.50787152
#   0.56183886  0.74625557         nan  0.50791706         nan] 0.585814270686
# ------------------
# 23
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58347894  0.69139184  0.75158148  0.54890951  0.5072387
#   0.52748163  0.74470904         nan  0.55747915         nan] 0.6140337867
# ------------------
# 24
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.56899015  0.64314048  0.70396959  0.61305396  0.50863555
#   0.5808438   0.7220068          nan  0.51286157         nan] 0.606687738769
# ------------------
# 25
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.64549111  0.61182092  0.76078587  0.58963378  0.50490888
#   0.57678804  0.76241429         nan  0.53354787         nan] 0.623173845951
# ------------------
# 26
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.60325505  0.66044326  0.78082288  0.5463867   0.50462957
#   0.56102262  0.75835082         nan  0.5088509          nan] 0.615470225124
# ------------------
# 27
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.59249     0.67187429  0.6657173   0.51789663  0.50500324
#   0.52226172  0.74156011         nan  0.49915979         nan] 0.58949538732
# ------------------
# 28
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61013781  0.6251764   0.74973894  0.604415    0.50613882
#   0.55000729  0.67703565         nan  0.50945411         nan] 0.60401300191
# ------------------
# 29
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.66185897  0.61905534  0.71293902  0.54247995  0.50654705
#   0.537133    0.7276073          nan  0.51328791         nan] 0.602613566455
# ------------------
# 30
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.66490567  0.63124472  0.58643748  0.55216861  0.50615645
#   0.55637558  0.71632337         nan  0.53134532         nan] 0.593119649752
# ------------------
# 31
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57709395  0.66729426  0.74526993  0.61436918  0.50627292
#   0.53437816  0.72864737         nan  0.49743494         nan] 0.608845088454
# ------------------
# 32
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.60929327  0.59876595  0.72007074  0.68384136  0.51365692
#   0.53832883  0.71180166         nan  0.50357566         nan] 0.60991679914
# ------------------
# 33
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.62733873  0.67308433  0.72781469  0.54647995  0.51070877
#   0.53385565  0.72422553         nan  0.51714186         nan] 0.607581187666
# ------------------
# 34
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.62187606  0.66721874  0.73846655  0.59725183  0.50994792
#   0.53110203  0.7596657          nan  0.50401737         nan] 0.616193274886
# ------------------
# 35
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61146974  0.61337982  0.76447446  0.55056573  0.50702637
#   0.52416756  0.75212305         nan  0.53524191         nan] 0.607306079491
# ------------------
# 36
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57760814  0.64738246  0.67561637  0.5199841   0.50584356
#   0.55013583  0.69856835         nan  0.52165359         nan] 0.587099047755
# ------------------
# 37
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.62563765  0.62446428  0.44031331  0.67428599  0.50522994
#   0.55068805  0.7584069          nan  0.50309668         nan] 0.585265350465
# ------------------
# 38
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.60432263  0.5794487   0.71745422  0.5297665   0.50432087
#   0.54426165  0.74745259         nan  0.52134416         nan] 0.593546415539
# ------------------
# 39
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61157907  0.62384942  0.75938289  0.55153765  0.50959849
#   0.53660945  0.68869394         nan  0.50301357         nan] 0.598033059637
# ------------------
# 40
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57941519  0.69109564  0.73210761  0.51380814  0.50472454
#   0.54354442  0.69259928         nan  0.52219034         nan] 0.597435643829
# ------------------
# 41
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.59261246  0.64387503  0.62388508  0.57055778  0.50498104
#   0.54038948  0.70326551         nan  0.52363064         nan] 0.587899627924
# ------------------
# 42
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57454578  0.63162029  0.71772847  0.56690922  0.50517657
#   0.53050085  0.68666194         nan  0.5124669          nan] 0.590701252662
# ------------------
# 43
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.59753639  0.67502134  0.71445425  0.52800994  0.50490267
#   0.56581057  0.70812608         nan  0.52296335         nan] 0.602103073707
# ------------------
# 44
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.59597555  0.67737587  0.70629622  0.53125032  0.50936497
#   0.57425313  0.71029056         nan  0.50670778         nan] 0.601439303345
# ------------------
# 45
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58427795  0.66542958  0.75964432  0.52979097  0.50078554
#   0.51776003  0.69316476         nan  0.5151142          nan] 0.595745916233
# ------------------
# 46
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.63408463  0.60559135  0.7152116   0.5773283   0.50609086
#   0.53246492  0.72797175         nan  0.55890398         nan] 0.607205922299
# ------------------
# 47
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.6003792   0.71399985  0.75961637  0.56633259  0.51091266
#   0.54988998  0.72215874         nan  0.50560407         nan] 0.616111683226
# ------------------
# 48
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.64658871  0.64207197  0.67485966  0.54859344  0.50742261
#   0.5379564   0.71768534         nan  0.53994388         nan] 0.601890248733
# ------------------
# 49
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.5813537   0.63297601  0.71689686  0.5409456   0.51466384
#   0.55343499  0.7922709          nan  0.498185           nan] 0.60384086301
# ------------------
# 50
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.60246351  0.62111118  0.73082045  0.53355196  0.50317461
#   0.54389498  0.71437203         nan  0.50867062         nan] 0.594757416189
# ------------------
# 51
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.60001607  0.59809427  0.72709057  0.54087526  0.50269914
#   0.53530606  0.71590545         nan  0.5200804          nan] 0.592508403212
# ------------------
# 52
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57055131  0.69135196  0.75507736  0.51732771  0.51193108
#   0.53933734  0.69955624         nan  0.52333523         nan] 0.601058529074
# ------------------
# 53
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58052975  0.65561124  0.71862917  0.64258544  0.50421412
#   0.53178391  0.72388881         nan  0.52382848         nan] 0.610133864133
# ------------------
# 54
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.62006965  0.67655311  0.69780647  0.57804675  0.5103441
#   0.60969315  0.72958329         nan  0.51797983         nan] 0.617509543792
# ------------------
# 55
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57862165  0.6142761   0.70587654  0.59664995  0.5101682
#   0.52187496  0.69129461         nan  0.50729222         nan] 0.590756778438
# ------------------
# 56
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.63799654  0.69208643  0.77611472  0.54229043  0.50225209
#   0.56276226  0.72399306         nan  0.49737531         nan] 0.61685885539
# ------------------
# 57
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57767101  0.63341083  0.74660734  0.57825976  0.50738207
#   0.56666472  0.72568279         nan  0.49829594         nan] 0.604246807402
# ------------------
# 58
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61784373  0.65975391  0.75907978  0.72455921  0.50501496
#   0.52716991  0.714205           nan  0.51346081         nan] 0.627635913115
# ------------------
# 59
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.6029647   0.6610326   0.71240642  0.58058206  0.50375927
#   0.53605945  0.72380717         nan  0.51828472         nan] 0.604862049699
# ------------------
# 60
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.65235753  0.65756317  0.72055392  0.58255655  0.50855706
#   0.57071873  0.74814261         nan  0.52029902         nan] 0.620093574734
# ------------------
# 61
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58867743  0.60027352  0.73020162  0.66324786  0.50795722
#   0.52378484  0.72367115         nan  0.52880094         nan] 0.608326823097
# ------------------
# 62
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.59657839  0.65514578  0.66539075  0.52340616  0.50544604
#   0.5304415   0.72366927         nan  0.50019155         nan] 0.587533680466
# ------------------
# 63
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58388129  0.66095685  0.72089641  0.60246097  0.51061819
#   0.55831265  0.70824247         nan  0.55233247         nan] 0.612212662938
# ------------------
# 64
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.62409906  0.6333597   0.76101922  0.52668201  0.50878719
#   0.55743902  0.76837912         nan  0.51329609         nan] 0.611632678364
# ------------------
# 65
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.65346033  0.67497984  0.75324571  0.52158159  0.51039898
#   0.5467932   0.69917908         nan  0.5393138          nan] 0.612369067749
# ------------------
# 66
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57212725  0.62468929  0.66544837  0.62512934  0.50897066
#   0.55847062  0.75517735         nan  0.51125962         nan] 0.60265906206
# ------------------
# 67
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.55733725  0.65873291  0.71171604  0.58346007  0.51362526
#   0.54419469  0.70024369         nan  0.50222837         nan] 0.59644228677
# ------------------
# 68
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.59743839  0.6536317   0.73403246  0.59604917  0.51006021
#   0.54524526  0.71928578         nan  0.52286212         nan] 0.609825636251
# ------------------
# 69
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.62497847  0.66643801  0.63093287  0.57020555  0.50679316
#   0.54349768  0.77283636         nan  0.52946275         nan] 0.605643105446
# ------------------
# 70
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.66219196  0.68471864  0.70805493  0.60656091  0.50542584
#   0.5508044   0.70086396         nan  0.50028537         nan] 0.614863248883
# ------------------
# 71
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61909449  0.67949984  0.71351652  0.54333862  0.51146904
#   0.54910939  0.67442082         nan  0.50806054         nan] 0.599813655786
# ------------------
# 72
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.73668178  0.67060718  0.77265871  0.59115819  0.50904815
#   0.57836736  0.72056499         nan  0.51853435         nan] 0.637202588536
# ------------------
# 73
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61540117  0.65030817  0.65861913  0.7070607   0.50233769
#   0.55508706  0.69253349         nan  0.49773942         nan] 0.60988585292
# ------------------
# 74
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.5871722   0.63717667  0.71203286  0.52633403  0.50984504
#   0.5348517   0.75917194         nan  0.52829738         nan] 0.599360226414
# ------------------
# 75
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.62041751  0.65121659  0.75097134  0.58897917  0.50875324
#   0.55275472  0.69565306         nan  0.50040538         nan] 0.608643876341
# ------------------
# 76
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.5938993   0.63549605  0.69461625  0.50821784  0.50777775
#   0.55031169  0.74769034         nan  0.50630484         nan] 0.593039255743
# ------------------
# 77
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.575756    0.67784228  0.77343053  0.5258332   0.51711062
#   0.55648461  0.70906007         nan  0.5135523          nan] 0.606133702027
# ------------------
# 78
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58860697  0.69687346  0.74736412  0.58396675  0.50654925
#   0.59665153  0.72801779         nan  0.51732877         nan] 0.620669829093
# ------------------
# 79
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.55724112  0.67713093  0.73182553  0.55348988  0.50915767
#   0.56409808  0.72217669         nan  0.51849118         nan] 0.604201384323
# ------------------
# 80
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57928218  0.60541334  0.704414    0.61650183  0.50406206
#   0.52602324  0.73491882         nan  0.50205816         nan] 0.596584204724
# ------------------
# 81
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.56008179  0.59337153  0.53937455  0.5469755   0.51124425
#   0.5448806   0.69387683         nan  0.50231788         nan] 0.561515365539
# ------------------
# 82
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.74141855  0.62975409  0.69600131  0.50991086  0.50970821
#   0.52763502  0.68833704         nan  0.51581546         nan] 0.602322567877
# ------------------
# 83
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57887175  0.6232936   0.7190413   0.53148265  0.50821448
#   0.54178352  0.692923           nan  0.50181884         nan] 0.587178642826
# ------------------
# 84
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57860679  0.66775637  0.74314776  0.6200727   0.50826696
#   0.55911243  0.78606218         nan  0.51408773         nan] 0.622139113784
# ------------------
# 85
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.59836617  0.62066846  0.64388128  0.59439356  0.51354554
#   0.55487256  0.75105108         nan  0.50890995         nan] 0.598211075859
# ------------------
# 86
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61925494  0.65429256  0.77380155  0.56796663  0.51029871
#   0.54034403  0.74205035         nan  0.51756475         nan] 0.615696688003
# ------------------
# 87
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.57056757  0.64486482  0.77386846  0.55192446  0.51036938
#   0.54595007  0.77570563         nan  0.50705538         nan] 0.610038220166
# ------------------
# 88
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.68976036  0.65709022  0.71291444  0.62727985  0.51059619
#   0.5374455   0.6984701          nan  0.52108034         nan] 0.619329624209
# ------------------
# 89
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.56433219  0.59101566  0.69237248  0.51731832  0.51022619
#   0.59515045  0.70267135         nan  0.52895413         nan] 0.587755097251
# ------------------
# 90
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58239028  0.73123278  0.72329337  0.51972023  0.50840301
#   0.56579974  0.71838132         nan  0.51099168         nan] 0.607526551199
# ------------------
# 91
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58510238  0.63497458  0.71162467  0.53418025  0.50531174
#   0.54820232  0.70833232         nan  0.51678446         nan] 0.59306408976
# ------------------
# 92
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61170311  0.61093241  0.56930984  0.58698102  0.50597853
#   0.55480305  0.74445667         nan  0.50468942         nan] 0.586106755583
# ------------------
# 93
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.6658466   0.60279232  0.72438268  0.6735409   0.50570795
#   0.54433884  0.71974822         nan  0.50679385         nan] 0.617893920688
# ------------------
# 94
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.68082065  0.68140935  0.7500956   0.58912739  0.50553297
#   0.52809494  0.7528331          nan  0.52699435         nan] 0.626863544095
# ------------------
# 95
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.56243114  0.65170403  0.72318119  0.53080591  0.50184536
#   0.55583506  0.72198329         nan  0.51422615         nan] 0.595251516414
# ------------------
# 96
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.61150485  0.68780711  0.74901784  0.56416569  0.50610049
#   0.56749219  0.73864231         nan  0.52910967         nan] 0.619230020061
# ------------------
# 97
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.6143592   0.67944758  0.7325593   0.51481181  0.50610131
#   0.55170944  0.70470488         nan  0.56690794         nan] 0.60882518185
# ------------------
# 98
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.67298005  0.61203166  0.66370245  0.61151752  0.50426369
#   0.52268023  0.70317703         nan  0.51133385         nan] 0.60021080935
# ------------------
# 99
# ["Another's Home" 'Arts & Entertainment' 'Food' 'Home' 'Nightlife Spot'
#  'Outdoors & Recreation' 'Professional Or Medical Office' 'Shop Or Store'
#  'Spiritual' 'Travel Or Transport' 'Work']
# [        nan  0.58732588  0.69192195  0.71064898  0.6343998   0.5136924
#   0.50937147  0.71894056         nan  0.51365345         nan] 0.60999430989
