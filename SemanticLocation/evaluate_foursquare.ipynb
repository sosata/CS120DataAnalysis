# %%
import os
import pickle
import pandas as pd
import numpy as np
import xgboost as xgb
from calculate_confusion_matrix import calculate_confusion_matrix
import time
from copy import deepcopy
from utils import one_hot_encoder
# from sklearn.preprocessing import OneHotEncoder
# from sklearn import preprocessing

save_results = True

n_boot = 100
split = 0.7
np.random.seed(seed=0)

ft_dir = 'features_long/'

# list feature files
files = os.listdir(ft_dir)

# reading top locations
with open('top_locations.dat','rb') as f:
    location_top = pickle.load(f)
f.close()

target_all = []
for filename in files:
    with open(ft_dir+filename, 'rb') as f:  
        _, target = pickle.load(f)

        # only keeping top locations
        ind = np.array([], int)
        for (i,loc) in enumerate(target['location']):
            if loc in location_top:
                ind = np.append(ind, i)
        target = target.loc[ind]
        target = target.reset_index(drop=True)
        
        target_all.append(target)
        
    f.close()

confs = []
aucs = []
labels = []
inds = np.arange(0,len(target_all),1)

for i in range(n_boot):
    
    print('------------------')
    print(i)
    
#     ind_boot = np.random.choice(inds, size=inds.size, replace=True)
    ind_boot = np.random.choice(inds, size=inds.size-int(np.floor(inds.size*split)), replace=False)
    
    y_report = pd.concat([target_all[j]['location'] for j in ind_boot], axis=0)
    y_fsq = pd.concat([target_all[j]['fsq'] for j in ind_boot], axis=0)
    
    # foursquare performance
    conf, roc_auc = calculate_confusion_matrix(y_fsq, y_report)
    
    labels.append(np.unique(y_report))
    confs.append(conf)
    aucs.append(roc_auc)

    print(np.unique(y_report))
    print(roc_auc, np.nanmean(roc_auc))
   
# saving the results
if save_results:
    with open('auc_location_new_10fold_fsq3.dat','wb') as f:
        pickle.dump([aucs, confs, labels], f)
    f.close()
# Out:
# ------------------
# 0
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.5688691   0.64662282  0.68290318  0.54787589  0.50456511
#          nan         nan] 0.59016722057
# ------------------
# 1
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.62021445  0.72236881  0.63204111  0.64187591  0.50729542
#          nan         nan] 0.624759141353
# ------------------
# 2
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.63249394  0.69217637  0.65750351  0.56376617  0.50610753
#          nan         nan] 0.610409503564
# ------------------
# 3
# /usr/local/lib/python3.4/dist-packages/sklearn/metrics/ranking.py:542: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.58916075  0.68710157  0.6833867   0.57930845  0.50192235
#          nan         nan] 0.608175966413
# ------------------
# 4
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.5833968   0.76566741  0.70905404  0.55632295  0.50863267
#          nan         nan] 0.624614776831
# ------------------
# 5
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.59297885  0.69691583  0.70547079  0.59283816  0.50035594
#          nan         nan] 0.617711913395
# ------------------
# 6
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.58378873  0.65249126  0.65224181  0.56437729  0.50060703
#          nan         nan] 0.590701223936
# ------------------
# 7
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.60796505  0.69473212  0.60703752  0.53569991  0.50700524
#          nan         nan] 0.590487968216
# ------------------
# 8
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.59827096  0.7233418   0.6825797   0.57675604  0.50277447
#          nan         nan] 0.616744596421
# ------------------
# 9
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.59181925  0.69849165  0.61095728  0.55239433  0.50034051
#          nan         nan] 0.590800605254
# ------------------
# 10
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.62175425  0.69670135  0.73638479  0.58639348  0.50698496
#          nan         nan] 0.629643767718
# ------------------
# 11
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.65154409  0.76789413  0.72705879  0.62547959  0.50581775
#          nan         nan] 0.655558868736
# ------------------
# 12
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.64676396  0.71049147  0.70915703  0.57177138  0.50491063
#          nan         nan] 0.628618891907
# ------------------
# 13
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.59879614  0.67672056  0.71344109  0.52596689  0.502991
#          nan         nan] 0.603583133711
# ------------------
# 14
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.65217008  0.65523312  0.6670604   0.58138208  0.50530874
#          nan         nan] 0.612230885497
# ------------------
# 15
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.62348485  0.70940764  0.70582523  0.59722249  0.50401579
#          nan         nan] 0.627991198895
# ------------------
# 16
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.56685021  0.61948461  0.69882023  0.52412192  0.50852538
#          nan         nan] 0.583560468563
# ------------------
# 17
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.60553648  0.67833748  0.68529335  0.60580492  0.50728029
#          nan         nan] 0.616450504725
# ------------------
# 18
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.643853    0.68549096  0.70557663  0.63828012  0.51220399
#          nan         nan] 0.63708094121
# ------------------
# 19
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.57774938  0.66672183  0.68383708  0.69882533  0.50677827
#          nan         nan] 0.626782377784
# ------------------
# 20
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.73211155  0.67879279  0.66304465  0.59455276  0.5044166
#          nan         nan] 0.634583671148
# ------------------
# 21
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.63986951  0.71905444  0.67883259  0.59586108  0.50661852
#          nan         nan] 0.628047226178
# ------------------
# 22
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.5686264   0.68853906  0.62474316  0.55903817  0.506027
#          nan         nan] 0.589394757067
# ------------------
# 23
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.57551712  0.71647442  0.70482778  0.55164571  0.50632363
#          nan         nan] 0.610957732942
# ------------------
# 24
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.5758466   0.68192291  0.67935918  0.62664346  0.50781769
#          nan         nan] 0.614317967944
# ------------------
# 25
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.64961028  0.63913033  0.70644685  0.583556    0.50299379
#          nan         nan] 0.616347449012
# ------------------
# 26
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.61032049  0.68824497  0.7174275   0.54692353  0.50284697
#          nan         nan] 0.613152693476
# ------------------
# 27
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.59217816  0.70556051  0.66742831  0.52063046  0.50396546
#          nan         nan] 0.597952581227
# ------------------
# 28
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.63722843  0.64594303  0.7098205   0.67205975  0.50604778
#          nan         nan] 0.634219896854
# ------------------
# 29
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.69412259  0.63272454  0.68882866  0.54421518  0.50486286
#          nan         nan] 0.612950765633
# ------------------
# 30
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.68800182  0.6588032   0.55783212  0.55467313  0.50533412
#          nan         nan] 0.59292887995
# ------------------
# 31
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.58269096  0.70352707  0.72312423  0.62744755  0.50586992
#          nan         nan] 0.628531948195
# ------------------
# 32
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.6192767   0.62997773  0.71507129  0.71111399  0.51299439
#          nan         nan] 0.63768682203
# ------------------
# 33
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.64724032  0.69546806  0.67109529  0.55547364  0.51006245
#          nan         nan] 0.615867952231
# ------------------
# 34
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.64933225  0.70845353  0.70560629  0.60264769  0.50873105
#          nan         nan] 0.634954162185
# ------------------
# 35
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.60339424  0.65240846  0.72421559  0.55695454  0.50694231
#          nan         nan] 0.608783026999
# ------------------
# 36
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.57967401  0.6882917   0.62767322  0.51916727  0.50513634
#          nan         nan] 0.583988509011
# ------------------
# 37
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.62941672  0.66127528  0.42356899  0.71024103  0.50422759
#          nan         nan] 0.585745921585
# ------------------
# 38
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.60330667  0.59395491  0.68154374  0.52648823  0.50286733
#          nan         nan] 0.581632174342
# ------------------
# 39
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.62833919  0.66353549  0.72858305  0.55272857  0.50921832
#          nan         nan] 0.616480924809
# ------------------
# 40
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.57503933  0.75915151  0.71035164  0.50779223  0.50420661
#          nan         nan] 0.611308263434
# ------------------
# 41
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.59121177  0.69382274  0.59763072  0.57545695  0.50372178
#          nan         nan] 0.592368789267
# ------------------
# 42
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.56775845  0.65626171  0.70482962  0.57236032  0.50419137
#          nan         nan] 0.601080295804
# ------------------
# 43
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.63398863  0.69876595  0.6276307   0.7456018   0.5013762
#          nan         nan] 0.641472657017
# ------------------
# 74
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.59098799  0.67390445  0.66555239  0.52459712  0.50874207
#          nan         nan] 0.592756805135
# ------------------
# 75
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.63405241  0.66283555  0.69848833  0.60140303  0.50761788
#          nan         nan] 0.620879440347
# ------------------
# 76
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.58986486  0.64402519  0.67534039  0.50804964  0.5056503
#          nan         nan] 0.58458607637
# ------------------
# 77
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.5720134   0.69905029  0.75173973  0.52277957  0.5196183
#          nan         nan] 0.613040258472
# ------------------
# 78
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.58307807  0.74456508  0.70235247  0.59315473  0.50478717
#          nan         nan] 0.625587503159
# ------------------
# 79
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.54640871  0.73235314  0.70349357  0.55674529  0.50797058
#          nan         nan] 0.609394257382
# ------------------
# 80
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.59213847  0.62017464  0.669952    0.61992629  0.5032062
#          nan         nan] 0.601079518841
# ------------------
# 81
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.57182023  0.62247819  0.57604373  0.55179144  0.51095591
#          nan         nan] 0.566617901202
# ------------------
# 82
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.76946773  0.64470244  0.6966127   0.5105645   0.50873478
#          nan         nan] 0.626016430797
# ------------------
# 83
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.5846863   0.65045965  0.67080167  0.531937    0.50717703
#          nan         nan] 0.589012330133
# ------------------
# 84
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.58476365  0.7021396   0.69462092  0.64323572  0.50756608
#          nan         nan] 0.626465194355
# ------------------
# 85
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.59524997  0.66196969  0.61240452  0.60209212  0.51301965
#          nan         nan] 0.596947189346
# ------------------
# 86
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.61991003  0.67594242  0.72888677  0.56578908  0.51007967
#          nan         nan] 0.620121593495
# ------------------
# 87
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.57466616  0.69963176  0.73480355  0.555474    0.50888552
#          nan         nan] 0.614692197043
# ------------------
# 88
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.74364663  0.67294837  0.68235774  0.64441497  0.50969473
#          nan         nan] 0.65061248861
# ------------------
# 89
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.56819832  0.62014858  0.66671636  0.51795945  0.50897767
#          nan         nan] 0.576400075504
# ------------------
# 90
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.58128173  0.8014869   0.70439609  0.52264929  0.50737559
#          nan         nan] 0.623437920821
# ------------------
# 91
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.59279891  0.68200714  0.69466233  0.53388289  0.50430568
#          nan         nan] 0.601531389496
# ------------------
# 92
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.61261298  0.63442677  0.53767913  0.60848666  0.50485325
#          nan         nan] 0.579611760494
# ------------------
# 93
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.68074588  0.63608282  0.68746561  0.71606532  0.50436326
#          nan         nan] 0.644944578106
# ------------------
# 94
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.69264591  0.72461122  0.71780778  0.59759631  0.5042816
#          nan         nan] 0.647388563505
# ------------------
# 95
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.56264211  0.6925242   0.6678418   0.5314308   0.50029628
#          nan         nan] 0.590947039166
# ------------------
# 96
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.61472289  0.72101754  0.7068257   0.56743471  0.50417743
#          nan         nan] 0.622835652975
# ------------------
# 97
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.62211619  0.70317372  0.70535303  0.51780347  0.50518426
#          nan         nan] 0.610726132482
# ------------------
# 98
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.70678567  0.64914664  0.63358721  0.64269112  0.50377003
#          nan         nan] 0.627196134081
# ------------------
# 99
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Spiritual (Church, Temple, Etc.)' 'Work']
# [        nan  0.58556901  0.72576325  0.69018163  0.69106668  0.51419685
#          nan         nan] 0.641355484559
