# %%
import os
import pickle
import pandas as pd
import numpy as np
import xgboost as xgb
from calculate_confusion_matrix import calculate_confusion_matrix
import time
from copy import deepcopy
from utils import one_hot_encoder
# from sklearn.preprocessing import OneHotEncoder
# from sklearn import preprocessing

save_results = True
do_stratify = False

n_boot = 100
split = 0.7
np.random.seed(seed=0)

ft_dir = 'features_long/'

# list feature files
files = os.listdir(ft_dir)

# reading top locations
with open('top_locations.dat') as f:
    location_top = pickle.load(f)
f.close()

target_all = []
for filename in files:
    with open(ft_dir+filename) as f:  
        _, target = pickle.load(f)

        # only keeping top locations
        ind = np.array([], int)
        for (i,loc) in enumerate(target['location']):
            if loc in location_top:
                ind = np.append(ind, i)
        target = target.loc[ind]
        target = target.reset_index(drop=True)
        
        target_all.append(target)
        
    f.close()

confs = []
aucs = []
labels = []
inds = np.arange(0,len(target_all),1)

for i in range(n_boot):
    
    print '------------------'
    print i
    
#     ind_boot = np.random.choice(inds, size=inds.size, replace=True)
    ind_boot = np.random.choice(inds, size=np.floor(inds.size*split), replace=False)
    
    y_report = pd.concat([target_all[j]['location'] for j in ind_boot], axis=0)
    y_fsq = pd.concat([target_all[j]['fsq'] for j in ind_boot], axis=0)
    
    # foursquare performance
    conf, roc_auc = calculate_confusion_matrix(y_fsq, y_report)
    
    labels.append(np.unique(y_report))
    confs.append(conf)
    aucs.append(roc_auc)

    print np.unique(y_report)
    print roc_auc, np.nanmean(roc_auc)
   
# saving the results
if save_results:
    with open('auc_location_new_10fold_fsq2.dat','w') as f:
        pickle.dump([aucs, confs, labels], f)
    f.close()
# Out:
# ------------------
# 0
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.59336755  0.62340761  0.70274916  0.58128389  0.50691652
#   0.54468878  0.74677439         nan  0.51205646         nan] 0.601405543233
# ------------------
# 1
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:58: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.58278827  0.64415455  0.68092724  0.54685542  0.50713693
#   0.54372812  0.72335949         nan  0.51199198         nan] 0.592617751081
# ------------------
# 2
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.59477397  0.64027286  0.73981733  0.55964556  0.50559703
#   0.54776306  0.73291915         nan  0.5142529          nan] 0.604380233001
# ------------------
# 3
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.58764058  0.65521681  0.73212706  0.61025544  0.50936302
#   0.54314585  0.71694405         nan  0.52455814         nan] 0.609906370085
# ------------------
# 4
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.61203757  0.6331416   0.713232    0.5263052   0.5060399
#   0.55009689  0.72763251         nan  0.51835803         nan] 0.598355462917
# ------------------
# 5
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.58530458  0.64852566  0.71353729  0.59701175  0.50422626
#   0.53539086  0.72679562         nan  0.5118416          nan] 0.602829202373
# ------------------
# 6
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.58156738  0.64667987  0.71554064  0.57211535  0.50700574
#   0.54254926  0.73455324         nan  0.51415637         nan] 0.601770980715
# ------------------
# 7
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.57569885  0.66105429  0.72277874  0.60297398  0.50936227
#   0.54562696  0.71556102         nan  0.51159885         nan] 0.60558187101
# ------------------
# 8
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.57955728  0.65643982  0.7379207   0.59025299  0.50560197
#   0.55765932  0.7202812          nan  0.51066917         nan] 0.607297807112
# ------------------
# 9
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.59043297  0.63571731  0.70609333  0.54855019  0.50860219
#   0.55089669  0.72940265         nan  0.50988086         nan] 0.597447023848
# ------------------
# 10
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.59953547  0.65298765  0.73182526  0.55791138  0.50792467
#   0.55584893  0.7214952          nan  0.51454983         nan] 0.605259798712
# ------------------
# 11
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.60112403  0.65116849  0.72332901  0.57085004  0.50625868
#   0.54556338  0.72596675         nan  0.51325512         nan] 0.604689437912
# ------------------
# 12
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.60990746  0.6509351   0.71689822  0.57627907  0.50857064
#   0.54710184  0.73099152         nan  0.51790215         nan] 0.607323249811
# ------------------
# 80
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.60993443  0.6251262   0.71590372  0.58232937  0.5079517
#   0.53627195  0.72545181         nan  0.5152668          nan] 0.602279498343
# ------------------
# 81
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.60874512  0.65751098  0.71327057  0.57237547  0.50647345
#   0.53737444  0.71922109         nan  0.52074791         nan] 0.604464880055
# ------------------
# 82
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.5924452   0.64306124  0.73219474  0.55128697  0.50897779
#   0.54888416  0.71076764         nan  0.51841993         nan] 0.600754708386
# ------------------
# 83
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.59279821  0.65741672  0.72479768  0.56960446  0.50608981
#   0.54650267  0.7248984          nan  0.51398539         nan] 0.604511665798
# ------------------
# 84
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.6147465   0.66361239  0.71206691  0.59771056  0.50701008
#   0.54493846  0.74352582         nan  0.5197403          nan] 0.612918877954
# ------------------
# 85
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.61397013  0.64866721  0.67606331  0.57045705  0.50827552
#   0.5476847   0.71317497         nan  0.51359425         nan] 0.598985891481
# ------------------
# 86
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.59240752  0.662959    0.72846929  0.57107837  0.50779759
#   0.54352293  0.70519515         nan  0.51993033         nan] 0.603920024478
# ------------------
# 87
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.61299447  0.62804756  0.69639433  0.58080811  0.50637964
#   0.54541157  0.72886434         nan  0.51728643         nan] 0.602023306344
# ------------------
# 88
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.60338682  0.65350206  0.73161438  0.54652576  0.50569141
#   0.54029702  0.71966753         nan  0.51323113         nan] 0.601739515664
# ------------------
# 89
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.60663634  0.6492253   0.73230462  0.55766892  0.50726575
#   0.5462807   0.72343105         nan  0.51873872         nan] 0.605193924103
# ------------------
# 90
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.58907648  0.64176367  0.72477515  0.56592505  0.50741539
#   0.55283364  0.71917128         nan  0.5103137          nan] 0.601409293403
# ------------------
# 91
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.60496411  0.65557254  0.73133181  0.55136166  0.507425
#   0.54994196  0.72712397         nan  0.51705199         nan] 0.605596629314
# ------------------
# 92
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.59083742  0.64537515  0.7206249   0.58356608  0.50339124
#   0.53953149  0.73489016         nan  0.52890852         nan] 0.605890619799
# ------------------
# 93
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.60846493  0.65858919  0.72000931  0.55594616  0.50732309
#   0.54266473  0.71479709         nan  0.513875           nan] 0.602708687975
# ------------------
# 94
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.60152029  0.65013568  0.72472334  0.56568914  0.50592949
#   0.53791252  0.70672531         nan  0.51928064         nan] 0.601489552384
# ------------------
# 95
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.59752566  0.62342378  0.71945057  0.5614499   0.5066652
#   0.55231724  0.72272628         nan  0.51316813         nan] 0.599590844932
# ------------------
# 96
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.60963935  0.64606316  0.72452937  0.54827846  0.5050183
#   0.55178504  0.73292631         nan  0.51684165         nan] 0.604385202477
# ------------------
# 97
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.59660106  0.6522354   0.73232111  0.54812593  0.50670535
#   0.54035084  0.71505573         nan  0.51679244         nan] 0.601023482918
# ------------------
# 98
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.61418304  0.63910359  0.746547    0.54989961  0.50772753
#   0.5401665   0.72198961         nan  0.50945399         nan] 0.603633858412
# ------------------
# 99
# ["Another's Home" 'Arts & Entertainment (Theater, Music Venue, Etc.)'
#  'Food (Restaurant, Cafe)' 'Home' 'Nightlife Spot (Bar, Club)'
#  'Outdoors & Recreation' 'Professional or Medical Office' 'Shop or Store'
#  'Spiritual (Church, Temple, Etc.)'
#  'Travel or Transport (Airport, Bus Stop, Train Station, Etc.)' 'Work']
# [        nan  0.61110862  0.66456594  0.75067597  0.56781933  0.506678
#   0.54382127  0.72029288         nan  0.51651373         nan] 0.61018446769

# %%
import numpy as np
